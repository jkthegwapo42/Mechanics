# %% [markdown]
# # Lesson 1: FORCE SYSTEMS

# %% [markdown]
# ## Force
#
# - A **force** is defined as action which tends to cause acceleration of a body.
# - It is **vector quantity** because its effect depends on the direction as well as on the magnitude of the action.
# - The complete specification of the action of a force must include its **magnitude**, **direction**, and **point of application**.

# %% [markdown]
# ## Two Dimensional Force Systems
#
# ### Rectangular Components
#
# - The most common two-dimensional resolution of a force vector is into rectangular components.
# - It follows the parallelogram rule
#
# $$\mathbf{F} = \mathbf{F_x}+\mathbf{F_y}$$
#
# where $\mathbf{F_x}$ and $\mathbf{F_y}$ are vector components of $\mathbf{F}$ in the *x*- and *y*- directions
#
# - Each of the two vector components may be written as a scalar times the appropriate unit vector.
# - In terms of unit vectors **i** and **j**
#
# $$\mathbf{F_x} = F_x\mathbf{i}\\
# F_x = F\cos{\theta}$$
#
# $$\mathbf{F_y} = F_y\mathbf{j}\\
# F_y = F\sin{\theta}$$
#
# $$F = \sqrt{F_x^2+F_y^2}$$
#
# $$\theta = \tan^{-1}\frac{F_y}{F_x}$$

# %% [markdown]
# ![Screenshot%20from%202022-07-10%2010-02-48.png](attachment:Screenshot%20from%202022-07-10%2010-02-48.png)

# %% [markdown]
# ## Example 1
#
# The forces $\mathbf{F_1}, \mathbf{F_2},$ and $\mathbf{F_3}$ all of which act on point *A* of the bracket are specified in three different ways. Determine the $x$ and $y$ scalar components of each of the three forces.
#
# ![Screenshot%20from%202022-07-10%2010-20-45.png](attachment:Screenshot%20from%202022-07-10%2010-20-45.png)

# %% [markdown]
# **Solution**

# %%
from math import sin, cos, pi, atan, sqrt
import handcalcs.render

# %%
# %%render params
#
# F_1 = 600 # kN
# F_2 = 500 # kN
# F_3 = 800 # kN
# Out:
# \[
# \begin{aligned}
# F_{1} &= 600 \; \;\textrm{(kN)}
#  &F_{2} &= 500 \; \;\textrm{(kN)}
#  &F_{3} &= 800 \; \;\textrm{(kN)}
# \\[10pt]
# \end{aligned}
# \]

# %%
# %%render
#
# theta_1 = 35*pi/180 # angle in radians
# theta_2 = atan (3/4) # angle in radians
# theta_3 = atan((0.3+0.1)/(0.4-0.2)) # angle in radians
# Out:
# \[
# \begin{aligned}
# \theta_{1} &= 35 \cdot \frac{ \pi }{ 180 }  = 35 \cdot \frac{ 3.142 }{ 180 } &= 6.109 \times 10 ^ {-1 } \; \;\textrm{(angle in radians)}
# \\[10pt]
# \theta_{2} &= \arctan \left( \frac{ 3 }{ 4 } \right) &= 6.435 \times 10 ^ {-1 } \; \;\textrm{(angle in radians)}
# \\[10pt]
# \theta_{3} &= \arctan \left( \frac{ 0.3 + 0.1 }{ 0.4 - 0.2 } \right) &= 1.107 \; \;\textrm{(angle in radians)}
# \end{aligned}
# \]

# %% [markdown]
# **x -components**

# %%
# %%render
#
# F_1x = F_1*cos(theta_1)
# F_2x = -F_2*cos(theta_2)
# F_3x = F_3*cos(theta_3)
# Out:
# \[
# \begin{aligned}
# F_{1x} &= F_{1} \cdot \cos \left( \theta_{1} \right)  = 600 \cdot \cos \left( 6.109 \times 10 ^ {-1 } \right) &= 491.491
# \\[10pt]
# F_{2x} &= \left( - F_{2} \right) \cdot \cos \left( \theta_{2} \right)  = \left( - 500 \right) \cdot \cos \left( 6.435 \times 10 ^ {-1 } \right) &= -400.0
# \\[10pt]
# F_{3x} &= F_{3} \cdot \cos \left( \theta_{3} \right)  = 800 \cdot \cos \left( 1.107 \right) &= 357.771
# \end{aligned}
# \]

# %% [markdown]
# **y-components**

# %%
# %%render
#
# F_1y = F_1*sin(theta_1)
# F_2y = F_2*sin(theta_2)
# F_3y = -F_3*sin(theta_3)
# Out:
# \[
# \begin{aligned}
# F_{1y} &= F_{1} \cdot \sin \left( \theta_{1} \right)  = 600 \cdot \sin \left( 6.109 \times 10 ^ {-1 } \right) &= 344.146
# \\[10pt]
# F_{2y} &= F_{2} \cdot \sin \left( \theta_{2} \right)  = 500 \cdot \sin \left( 6.435 \times 10 ^ {-1 } \right) &= 300.0
# \\[10pt]
# F_{3y} &= \left( - F_{3} \right) \cdot \sin \left( \theta_{3} \right)  = \left( - 800 \right) \cdot \sin \left( 1.107 \right) &= -715.542
# \end{aligned}
# \]

# %% [markdown]
# ## Example 2
#
# The 500 N force **F** is applied to the vertical pole as shown. (1) Write **F** in terms of unit vectors **i** and **j** and identify both its vector and scalar components. (2) Determine the scalar components of the force vector **F** along the $x'-$ and $y'-$ axes. Determine the scalar componets of **F** along the $x-$ and $y'-$ axes.
#
# ![Screenshot%20from%202022-07-10%2010-49-35.png](attachment:Screenshot%20from%202022-07-10%2010-49-35.png)

# %% [markdown]
# ## Solution

# %% [markdown]
# **Part 1**

# %%
# %%render
#
# F = 500 # kN
# theta_1 = (90-30)*pi/180 # angle in radians
#
# F_x = F*cos(theta_1)
# F_y = -F*sin(theta_1)
# Out:
# \[
# \begin{aligned}
# F &= 500 \; \;\textrm{(kN)}
# \\[10pt]
# \theta_{1} &= \left( 90 - 30 \right) \cdot \frac{ \pi }{ 180 }  = \left( 90 - 30 \right) \cdot \frac{ 3.142 }{ 180 } &= 1.047 \; \;\textrm{(angle in radians)}
# \\[10pt]
# F_{x} &= F \cdot \cos \left( \theta_{1} \right)  = 500 \cdot \cos \left( 1.047 \right) &= 250.0
# \\[10pt]
# F_{y} &= \left( - F \right) \cdot \sin \left( \theta_{1} \right)  = \left( - 500 \right) \cdot \sin \left( 1.047 \right) &= -433.013
# \end{aligned}
# \]

# %%
from sympy import symbols

# %%
i = symbols("i")
j = symbols ("j")

# %%
# %%render sympy
#
# F = F_x*i+F_y*j
# Out:
# \[
# \begin{aligned}
# F &= F_{x} \cdot i + F_{y} \cdot j  = 250.0 \cdot \displaystyle i + -433.013 \cdot \displaystyle j &= \displaystyle 250.0 i - 433.013 j
# \end{aligned}
# \]

# %% [markdown]
# **Part 2**

# %%
i_prime = symbols("i_prime")
j_prime = symbols("j_prime")

# %%
# %%render sympy
#
# F_x_prime = 500
#
# F_y_prime = 0
#
# F_prime = F_x_prime*i_prime + F_y_prime*j_prime
# Out:
# \[
# \begin{aligned}
# F_{x'} &= 500 \;
# \\[10pt]
# F_{y'} &= 0 \;
# \\[10pt]
# F' &= F_{x'} \cdot i' + F_{y'} \cdot j'  = 500 \cdot i' + 0 \cdot j' &= \displaystyle 500 i_{prime}
# \end{aligned}
# \]

# %% [markdown]
# **Part 3**
#
# ![Screenshot%20from%202022-07-10%2011-10-30.png](attachment:Screenshot%20from%202022-07-10%2011-10-30.png)

# %% [markdown]
# Use sine law to solve the components
#
# $$\frac{F_x}{\sin{90}} = \frac{500}{\sin{30}}$$
#
# $$\frac{F_{y'}}{\sin{60}}= \frac{500}{\sin{30}}$$

# %%
# %%render
#
# F_x = 500*sin(90*pi/180)/sin(30*pi/180)
#
# F_y_prime = 500*sin(60*pi/180)/sin(30*pi/180)
# Out:
# \[
# \begin{aligned}
# F_{x} &= 500 \cdot \frac{ \sin \left( 90 \cdot \frac{ \pi }{ 180 } \right) }{ \sin \left( 30 \cdot \frac{ \pi }{ 180 } \right) } \\&= 500 \cdot \frac{ \sin \left( 90 \cdot \frac{ 3.142 }{ 180 } \right) }{ \sin \left( 30 \cdot \frac{ 3.142 }{ 180 } \right) } \\&= 1000.0  \\
# \\[10pt]
# F_{y'} &= 500 \cdot \frac{ \sin \left( 60 \cdot \frac{ \pi }{ 180 } \right) }{ \sin \left( 30 \cdot \frac{ \pi }{ 180 } \right) } \\&= 500 \cdot \frac{ \sin \left( 60 \cdot \frac{ 3.142 }{ 180 } \right) }{ \sin \left( 30 \cdot \frac{ 3.142 }{ 180 } \right) } \\&= 866.025  \\
# \end{aligned}
# \]

# %% [markdown]
# ## Resultant
#
# Rectangular components are convenient for finding the sum or resultant **R** of two or more forces which are concurrent.
#
# ![Screenshot%20from%202022-07-10%2011-58-14.png](attachment:Screenshot%20from%202022-07-10%2011-58-14.png)

# %% [markdown]
# From the figure:
#
# $$\mathbf{R} = \mathbf{F_1}+\mathbf{F_2}\\
# \mathbf{R} = F_x\mathbf{i} + F_y\mathbf{j}$$
#
# $$R_x = \sum{F_x}\\
# R_y = \sum{F_y}$$
#
# $$R = \sqrt{R_x^2+R_y^2}$$
#
# $$\theta = \tan^-1\frac{R_y}{R_x}$$

# %% [markdown]
# ## Example 3
#
# The two structural members, one of which is in tension and the other in compression, exert the indicated forces on joint *O*. Determine the magnitude of the resultant **R** of the two forces and the angle $\theta$ which **R** makes with the positive $x-$ axis.
#
# ![Screenshot%20from%202022-07-10%2012-18-27.png](attachment:Screenshot%20from%202022-07-10%2012-18-27.png)

# %% [markdown]
# ### Solution

# %%
# %%render
#
# F_1 = 2 # kN
# F_2 = 3 # kN
#
# theta_1 = 30*pi/180 # radians
# theta_2 = atan(4/3) # radians
# Out:
# \[
# \begin{aligned}
# F_{1} &= 2 \; \;\textrm{(kN)}
# \\[10pt]
# F_{2} &= 3 \; \;\textrm{(kN)}
# \\[10pt]
# \theta_{1} &= 30 \cdot \frac{ \pi }{ 180 }  = 30 \cdot \frac{ 3.142 }{ 180 } &= 5.236 \times 10 ^ {-1 } \; \;\textrm{(radians)}
# \\[10pt]
# \theta_{2} &= \arctan \left( \frac{ 4 }{ 3 } \right) &= 9.273 \times 10 ^ {-1 } \; \;\textrm{(radians)}
# \end{aligned}
# \]

# %%
# %%render
#
# F_1x = F_1*cos(theta_1)
# F_2x = F_2*cos(theta_2)
#
# F_1y = F_1*sin(theta_1)
# F_2y = -F_2*sin(theta_2)
#
# R_x = F_1x+F_2x
# R_y = F_1y+F_2y
# Out:
# \[
# \begin{aligned}
# F_{1x} &= F_{1} \cdot \cos \left( \theta_{1} \right)  = 2 \cdot \cos \left( 5.236 \times 10 ^ {-1 } \right) &= 1.732
# \\[10pt]
# F_{2x} &= F_{2} \cdot \cos \left( \theta_{2} \right)  = 3 \cdot \cos \left( 9.273 \times 10 ^ {-1 } \right) &= 1.8
# \\[10pt]
# F_{1y} &= F_{1} \cdot \sin \left( \theta_{1} \right)  = 2 \cdot \sin \left( 5.236 \times 10 ^ {-1 } \right) &= 1.0
# \\[10pt]
# F_{2y} &= \left( - F_{2} \right) \cdot \sin \left( \theta_{2} \right)  = \left( - 3 \right) \cdot \sin \left( 9.273 \times 10 ^ {-1 } \right) &= -2.4
# \\[10pt]
# R_{x} &= F_{1x} + F_{2x}  = 1.732 + 1.8 &= 3.532
# \\[10pt]
# R_{y} &= F_{1y} + F_{2y}  = 1.0 + -2.4 &= -1.4
# \end{aligned}
# \]

# %% [markdown]
# Calculate the resultant **R**

# %%
# %%render
#
# R = sqrt(R_x**2+R_y**2)
#
# theta = atan(R_y/R_x)*180/pi
# Out:
# \[
# \begin{aligned}
# R &= \sqrt { \left( R_{x} \right) ^{ 2 } + \left( R_{y} \right) ^{ 2 } }  = \sqrt { \left( 3.532 \right) ^{ 2 } + \left( -1.4 \right) ^{ 2 } } &= 3.799
# \\[10pt]
# \theta &= \arctan \left( \frac{ R_{y} }{ R_{x} } \right) \cdot \frac{ 180 }{ \pi }  = \arctan \left( \frac{ -1.4 }{ 3.532 } \right) \cdot \frac{ 180 }{ 3.142 } &= -21.622
# \end{aligned}
# \]

# %% [markdown]
# ## Problem 1
# Determine the magnitude of the resultant force acting on the screw eye and its direction measured clockwise from the $x-$ axis.
#
# ![Screenshot%20from%202022-07-11%2011-47-07.png](attachment:Screenshot%20from%202022-07-11%2011-47-07.png)

# %% [markdown]
# ## Problem 2
#
# If $\theta_x = 30^o$ and $F_2 = 6 kN$, determine the magnitude of the resultant force acting on the plate and its direction measured clockwise from the positive $x-$ axis.
#
# ![Screenshot%20from%202022-07-11%2011-52-25.png](attachment:Screenshot%20from%202022-07-11%2011-52-25.png)

# %% [markdown]
# ## Problem 3
#
# Resolve the force $\mathbf{F_1}$ into components acting along the $\mu$ and $\nu$ axes and determine the magnitudes of the components.
#
# ![Screenshot%20from%202022-07-11%2011-59-23.png](attachment:Screenshot%20from%202022-07-11%2011-59-23.png)

# %% [markdown]
# ## Problem 4
#
# If the magnitude of the resultant force is to be 500 N, directed along the positive $y-$ axis, determine the magnitude of force **F** and its direction $\theta$.
#
# ![Screenshot%20from%202022-07-11%2012-03-11.png](attachment:Screenshot%20from%202022-07-11%2012-03-11.png)

# %% [markdown]
# ## Problem 5
#
# Determine the angle $\theta$ for connecting member *A* to the plate so that the resultant force of $\mathbf{F_A}$ and $\mathbf{F_B}$ is directed horizontally to the right. Also, what is the magnitude of the resultant force?
#
# ![Screenshot%20from%202022-07-11%2012-08-07.png](attachment:Screenshot%20from%202022-07-11%2012-08-07.png)
